# %%
for i in range(2,-2,-1):
    try:
        print(3/i)
    except ZeroDivisionError:
        pass
# Out:
# 1.5
# 3.0
# -3.0

# %%
import os,re

# %%
with open(r"D:\GOD's folder\자료\대학교\언어학\프로그래밍 연습\교수님 자료\regex_sample\regex_sample.txt", 'r', encoding='cp949') as inF:
    txt = inF.read()

# %%
print(txt)
# Out:
# 문재인 대통령·아베 신조 일본 총리·리커창 중국 국무원 총리가 9일 문 대통령과 김정은 북한 국무위원장이 지난 4월 남북 정상회담에서 합의한 ‘판문점 선언’에 대해 지지를 표명했다.
#
# 한·일·중 3국 정상은 이날 일본 도쿄 내각부 영빈관에서 열린 3개국 정상회의 후 특별성명을 통해 “일본과 중국의 정상들은 특히 지난 4월 27일 남북정상회담에서 한반도의 완전한 비핵화와 항구적 평화체제 구축을 공동 목표로 확인하고, 문 대통령과 김정은 위원장간 합의된 ‘한반도 평화·번영 및 통일을 위한 판문점 선언’을 평가하고 환영한다”고 밝혔다.
#
# 이들은 “금번 남북정상회담 결과를 토대로, 특히 다가오는 미·북 정상회담 등 관련 당사국들의 추가 노력들이 역내 평화와 안전을 위해 당사국들의 우려들을 포괄적으로 해결하는데 기여하기를 강력하게 희망한다”며 “한반도와 동북아에서의 평화와 안정을 유지하는 것이 우리의 공동 이해이자 책임이라는 점을 재확인한다”고 강조했다. 이어 “3국 정상은 이러한 목표를 위해 공동의 노력을 강화해 나갈 것”이라고 덧붙였다.
#
# 이하는 특별 성명문 전문.
#
# 1. 우리 일본, 중국, 한국 정상들은, 현재 북한을 둘러싼 긍정적인 진전을 위해 그간 국제사회가 경주해온 모든 노력들을 평가한다. 일본과 중국의 정상들은 특히 4월 27일 역사적인 2018년 남북정상회담에서 한반도의 완전한 비핵화와 항구적 평화체제 구축을 공동 목표로 확인하고 문재인 대통령과 김정은 위원장간 합의된 ‘한반도 평화, 번영 및 통일을 위한 판문점 선언’을 평가하고 환영한다.
#
# 2. 우리 일본, 중국, 한국 정상들은 금번 남북정상회담 결과를 토대로, 특히 다가오는 북미정상회담 등 관련 당사국들의 추가 노력들이 역내 평화와 안전을 위해 당사국들의 우려들을 포괄적으로 해결하는데 기여하기를 강력하게 희망한다.
#
# ...

# %%
re.findall('정상[가-힣]*', txt)
# Out:
# ['정상회담에서',
#  '정상은',
#  '정상회의',
#  '정상들은',
#  '정상회담에서',
#  '정상회담',
#  '정상회담',
#  '정상은',
#  '정상들은',
#  '정상들은',
#  '정상회담에서',
#  '정상들은',
#  '정상회담',
#  '정상회담',
#  '정상회담에서',
#  '정상은',
#  '정상회의',
#  '정상들은',
#  '정상회담에서',
#  '정상회담',
#  '정상회담',
#  '정상은',
#  '정상들은',
#  '정상들은',
#  '정상회담에서',
#  '정상들은',
#  '정상회담',
#  '정상회담',
#  '정상회담',
#  '정상회담',
#  '정상회담',
#  '정상회담',
#  '정상회담',
#  '정상회담의',
#  '정상회담',
#  '정상회담을',
#  '정상회담',
#  '정상회담',
#  '정상회담']
