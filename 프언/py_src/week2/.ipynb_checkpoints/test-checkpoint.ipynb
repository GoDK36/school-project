# %% [markdown]
# # 첫번째
# ## 두 번째
# ### 세번째

# %% [markdown]
# >김신우 짱짱맨

# %% [markdown]
# $c = \sqrt{a^2 + b^2}$

# %% [markdown]
# $k_{n+1} = n^2 + k_{n-1}$

# %%
a=3
b=2
a+b
# Out:
# 5

# %%
2<3
# Out:
# True

# %%
k="김신우는 천재"
#이 명제는 불변이다

# %%
x = "X"
s = "XYZ"
t = "Y"
n = 3

# %%
s > x
# Out:
# True

# %%
s*t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c32055f6c999> in <module>
# ----> 1 s*t
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s*n
# Out:
# 'XYZXYZXYZ'

# %%
x*n
# Out:
# 'XXX'

# %%
s[1]
# Out:
# 'Y'

# %%
s * n
# Out:
# 'XYZXYZXYZ'

# %%
x * 13
# Out:
# 'XXXXXXXXXXXXX'

# %%
s * 3
# Out:
# 'XYZXYZXYZ'

# %%
s * int(n)
# Out:
# 'XYZXYZXYZ'

# %%
len(s)
# Out:
# 3

# %%
l = '나\n너'
print(l)
# Out:
# 나
# 너

# %%
multiline = '''
# Out:
#   File "<ipython-input-21-4822e9e23de3>", line 1
#     multiline = '''
#                    ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
multiline = '''
Life is too short
You need Python
'''

# %%
print(multiline)
# Out:
# Life is too short
# You need Python

# %%
name = input("이름을 입력하세요 : ")
# Out:
# 이름을 입력하세요 : 시누찡

# %%
print(name)
# Out:
# 시누찡

# %%
k = ("It is good to meet you, ")

# %%
print(k + name)
# Out:
# It is good to meet you, 시누찡

# %%
s= "Life is too short, You need Python"
s[0]
# Out:
# 'L'

# %%
s[6]
# Out:
# 's'

# %%
s[-1]
# Out:
# 'n'

# %%
s[0:5]
# Out:
# 'Life '

# %%
a = "abcdef"

# %%
a[0:3]
# Out:
# 'abc'

# %%
s[0:2]
# Out:
# 'Li'

# %%
s[5:7]
# Out:
# 'is'

# %%
s[-17:-21]
# Out:
# ''

# %%
s[-21:-17]
# Out:
# 'hort'

# %%
s[-21:-16]
# Out:
# 'hort,'

# %%
s[-22:-17]
# Out:
# 'short'

# %%
a = "20010331Rainy"

# %%
year = a[:4]

# %%
month = a[4:6]

# %%
day = a[6:8]

# %%
wheather = a[-5:]

# %%
print(day)
# Out:
# 31

# %%
print(year)
# Out:
# 2001

# %%
print(month)
# Out:
# 03

# %%
print(wheather)
# Out:
# Rainy

# %%
k = 'like a cat'

# %%
chng = k[6:7]

# %%
z = k[:5]

# %%
e = k[7:]

# %%
print(z + "the " + e)
# Out:
# like the cat

# %%
k = k.replace(' a ',' the ')
print(k)
# Out:
# like the cat

# %%
s = "          aa      "

# %%
s.strip()
# Out:
# 'aa'

# %%
s.lstrip()
# Out:
# 'aa      '

# %%
s.rstrip()
# Out:
# '          aa'

# %%
k.startswith('l')
# Out:
# True

# %%
k.endswith('T')
# Out:
# False

# %%
print(k)
# Out:
# like the cat

# %%
s = "2354"

# %%
type(s)
# Out:
# str

# %%
s.zfill(236654)
# Out:
# '...'

# %%
print(s)
# Out:
# 2354

# %%
atc = """세계보건기구(WHO)가 유전자 편집 전문가 위원회를 꾸리고 인간 배아에 대한 유전자 편집과 관련된 모든 임상 연구를 일시적으로 중단하라고 촉구하는 입장을 내놨다. 또 유전자 편집 연구를 투명하게 볼 수 있도록 국제적 등록기관을 만들어야 한다고 촉구했다. 

 

WHO의 이런 입장은 지난해 11월 중국 허젠쿠이(賀建奎) 중국 난팡과기대 교수가 유전자를 편집해 일명 '디자이너 베이비'를 탄생시킨 뒤 일어난 논란에 대한 대책의 일환이다. 허젠쿠이 교수는 유튜브 영상을 통해 유전자가위인 크리스퍼 유전자 가위(CRISPR-Cas9)로 수정란의 유전자를 편집해, 에이즈(AIDS·후천성면역결핍증)에 면역력을 가진 쌍둥이 ‘룰루’와 ‘나나’를 탄생시켰다고 주장했다. 그는 2018년 국제 학술지 ‘네이처’가 선정한 올해 과학계 10대 인물에 선정될 만큼 화제를 모았지만, 한편으로는 심각한 연구 윤리 위반이라며 학계의 비난에 휩싸였다.

 

지난 14일에는 미국 매사추세츠공대(MIT)와 독일 막스플랑크연구소를 비롯한 세계 과학자들이 국제학술지 '네이처'를 통해 정자, 난자 등 인간의 생식세포와 수정란을 이용한 유전자 편집 기술을 임상에 적용하는 것을 잠정 중단해야 한다는 모라토리엄을 선언하기도 했다. 

 

WHO 전문가위원회를 이끄는 마거릿 함부르크 공동의장은 "모호한 모라토리엄은 해결책이 될 수 없다"면서 "현재 인간의 생식세포를 이용한 유전자 편집 기술을 임상에 적용하는 것은 무책임하다"고 말했다.

 

과학자들이 유전자 편집 기술 임상 연구에 대해 부정적으로 생각하는 이유는 유전자가 가진 모든 기능을 알 수 없는데다, 여러 유전자가 복합적으로 상호작용하기 때문이다. 가령 허젠쿠이 교수가 디자이너 베이비를 만들 때 없앤 CCR5 유전자는 에이즈 감염에 취약하다는 특성이 있지만 한편에선 건강 유지에 꼭 필요한 기능이 있을 수 있다는 반론이 제기되고 있다. """

# %%
print(len(atc.split()))
# Out:
# 201

# %%
natc = atc.replace('인간', '사람')

# %%
print(natc)
# Out:
# 세계보건기구(WHO)가 유전자 편집 전문가 위원회를 꾸리고 사람 배아에 대한 유전자 편집과 관련된 모든 임상 연구를 일시적으로 중단하라고 촉구하는 입장을 내놨다. 또 유전자 편집 연구를 투명하게 볼 수 있도록 국제적 등록기관을 만들어야 한다고 촉구했다.
#
#
#
# WHO의 이런 입장은 지난해 11월 중국 허젠쿠이(賀建奎) 중국 난팡과기대 교수가 유전자를 편집해 일명 '디자이너 베이비'를 탄생시킨 뒤 일어난 논란에 대한 대책의 일환이다. 허젠쿠이 교수는 유튜브 영상을 통해 유전자가위인 크리스퍼 유전자 가위(CRISPR-Cas9)로 수정란의 유전자를 편집해, 에이즈(AIDS·후천성면역결핍증)에 면역력을 가진 쌍둥이 ‘룰루’와 ‘나나’를 탄생시켰다고 주장했다. 그는 2018년 국제 학술지 ‘네이처’가 선정한 올해 과학계 10대 인물에 선정될 만큼 화제를 모았지만, 한편으로는 심각한 연구 윤리 위반이라며 학계의 비난에 휩싸였다.
#
#
#
# 지난 14일에는 미국 매사추세츠공대(MIT)와 독일 막스플랑크연구소를 비롯한 세계 과학자들이 국제학술지 '네이처'를 통해 정자, 난자 등 사람의 생식세포와 수정란을 이용한 유전자 편집 기술을 임상에 적용하는 것을 잠정 중단해야 한다는 모라토리엄을 선언하기도 했다.
#
#
#
# WHO 전문가위원회를 이끄는 마거릿 함부르크 공동의장은 "모호한 모라토리엄은 해결책이 될 수 없다"면서 "현재 사람의 생식세포를 이용한 유전자 편집 기술을 임상에 적용하는 것은 무책임하다"고 말했다.
#
#
#
# 과학자들이 유전자 편집 기술 임상 연구에 대해 부정적으로 생각하는 이유는 유전자가 가진 모든 기능을 알 수 없는데다, 여러 유전자가 복합적으로 상호작용하기 때문이다. 가령 허젠쿠이 교수가 디자이너 베이비를 만들 때 없앤 CCR5 유전자는 에이즈 감염에 취약하다는 특성이 있지만 한편에선 건강 유지에 꼭 필요한 기능이 있을 수 있다는 반론이 제기되고 있다.

# %%
natc.count('사람')
# Out:
# 3

# %%
knatc = natc.strip()
#왜 strip은 안되는겨

# %%
knatc.count('미국')
# Out:
# 1

# %%
len(knatc)
# Out:
# 936

# %%
print(knatc)
# Out:
# 세계보건기구(WHO)가 유전자 편집 전문가 위원회를 꾸리고 사람 배아에 대한 유전자 편집과 관련된 모든 임상 연구를 일시적으로 중단하라고 촉구하는 입장을 내놨다. 또 유전자 편집 연구를 투명하게 볼 수 있도록 국제적 등록기관을 만들어야 한다고 촉구했다.
#
#
#
# WHO의 이런 입장은 지난해 11월 중국 허젠쿠이(賀建奎) 중국 난팡과기대 교수가 유전자를 편집해 일명 '디자이너 베이비'를 탄생시킨 뒤 일어난 논란에 대한 대책의 일환이다. 허젠쿠이 교수는 유튜브 영상을 통해 유전자가위인 크리스퍼 유전자 가위(CRISPR-Cas9)로 수정란의 유전자를 편집해, 에이즈(AIDS·후천성면역결핍증)에 면역력을 가진 쌍둥이 ‘룰루’와 ‘나나’를 탄생시켰다고 주장했다. 그는 2018년 국제 학술지 ‘네이처’가 선정한 올해 과학계 10대 인물에 선정될 만큼 화제를 모았지만, 한편으로는 심각한 연구 윤리 위반이라며 학계의 비난에 휩싸였다.
#
#
#
# 지난 14일에는 미국 매사추세츠공대(MIT)와 독일 막스플랑크연구소를 비롯한 세계 과학자들이 국제학술지 '네이처'를 통해 정자, 난자 등 사람의 생식세포와 수정란을 이용한 유전자 편집 기술을 임상에 적용하는 것을 잠정 중단해야 한다는 모라토리엄을 선언하기도 했다.
#
#
#
# WHO 전문가위원회를 이끄는 마거릿 함부르크 공동의장은 "모호한 모라토리엄은 해결책이 될 수 없다"면서 "현재 사람의 생식세포를 이용한 유전자 편집 기술을 임상에 적용하는 것은 무책임하다"고 말했다.
#
#
#
# 과학자들이 유전자 편집 기술 임상 연구에 대해 부정적으로 생각하는 이유는 유전자가 가진 모든 기능을 알 수 없는데다, 여러 유전자가 복합적으로 상호작용하기 때문이다. 가령 허젠쿠이 교수가 디자이너 베이비를 만들 때 없앤 CCR5 유전자는 에이즈 감염에 취약하다는 특성이 있지만 한편에선 건강 유지에 꼭 필요한 기능이 있을 수 있다는 반론이 제기되고 있다.

# %%
knatc = natc.replace(' ', '')

# %%
print(knatc)
# Out:
# 세계보건기구(WHO)가유전자편집전문가위원회를꾸리고사람배아에대한유전자편집과관련된모든임상연구를일시적으로중단하라고촉구하는입장을내놨다.또유전자편집연구를투명하게볼수있도록국제적등록기관을만들어야한다고촉구했다.
#
#
#
# WHO의이런입장은지난해11월중국허젠쿠이(賀建奎)중국난팡과기대교수가유전자를편집해일명'디자이너베이비'를탄생시킨뒤일어난논란에대한대책의일환이다.허젠쿠이교수는유튜브영상을통해유전자가위인크리스퍼유전자가위(CRISPR-Cas9)로수정란의유전자를편집해,에이즈(AIDS·후천성면역결핍증)에면역력을가진쌍둥이‘룰루’와‘나나’를탄생시켰다고주장했다.그는2018년국제학술지‘네이처’가선정한올해과학계10대인물에선정될만큼화제를모았지만,한편으로는심각한연구윤리위반이라며학계의비난에휩싸였다.
#
#
#
# 지난14일에는미국매사추세츠공대(MIT)와독일막스플랑크연구소를비롯한세계과학자들이국제학술지'네이처'를통해정자,난자등사람의생식세포와수정란을이용한유전자편집기술을임상에적용하는것을잠정중단해야한다는모라토리엄을선언하기도했다.
#
#
#
# WHO전문가위원회를이끄는마거릿함부르크공동의장은"모호한모라토리엄은해결책이될수없다"면서"현재사람의생식세포를이용한유전자편집기술을임상에적용하는것은무책임하다"고말했다.
#
#
#
# 과학자들이유전자편집기술임상연구에대해부정적으로생각하는이유는유전자가가진모든기능을알수없는데다,여러유전자가복합적으로상호작용하기때문이다.가령허젠쿠이교수가디자이너베이비를만들때없앤CCR5유전자는에이즈감염에취약하다는특성이있지만한편에선건강유지에꼭필요한기능이있을수있다는반론이제기되고있다.

# %%
len(knatc)
# Out:
# 734

# %%
s = "34"

# %%
s= int(s)

# %%
s
# Out:
# 34

# %%
type(s)
# Out:
# int

# %%
float(3.141592)
# Out:
# 3.141592

# %%
a = input("숫자를 입력하세요: ")
b = input("number: ")
c = input("number: ")
print(int(a)+int(b) +int(c))
# Out:
# 숫자를 입력하세요: 6
# number: 6
# number: 6
# 18

# %%
print(int(sum(a+b+c)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-4ba837ec8e2b> in <module>
# ----> 1 print(int(sum(a+b+c)))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
age = input("How old are you? ")
print("I'm " + age + " year's old")
# Out:
# How old are you? ddd
# I'm ddd year's old

# %%
print(int(age)."years old.")
# Out:
#   File "<ipython-input-77-230556b8bc3e>", line 1
#     print(int(age)."years old.")
#                               ^
# SyntaxError: invalid syntax

# %%
nage = 12
m = 'month'
y= 'year'

# %%
print(age, "years old")
# Out:
# ddd years old

# %%
print('{} years old'.format(nage))
# Out:
# 12 years old

# %%
print("{} {}s old".format(nage, m))
# Out:
# 12 monthss old

# %%
m
# Out:
# '03'

# %%
f'{nage} {y}s old'
# Out:
# '12 years old'
