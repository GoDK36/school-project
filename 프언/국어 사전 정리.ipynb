# %%
dic = {
    '쏘다1':{
        'sense':{
            '1':{
                '뜻  ':"활이나 총, 대포 따위를 일정한 목표를 향하여 발사하다.",
                '예제':['적의 진지에 대포를 쏘다']
            },
            '2':{
                '뜻':'말이나 시선으로 상대편을 매섭게 공격하다.',
                '예제':['버릇없는 아이에게 따끔한 말을 한마디 쏘다']
            },
            '3':{
                '뜻':'벌레가 침과 같은 것으로 살을 찌르다.',
                '예제':['벌이 얼굴을 쏘다']
            },
            '4':{
                '뜻':'매운맛이나 강한 냄새가 사람의 입 안이나 코를 강하게 자극하다.',
                '예제':['고추가 입 안을 쏘다']
            }
        },
        '품사':'동사',
        '발음':'쏘:다',
        '어원':['쏘다','소다','ㅂ소다'],
        '활용':['쏘아','쏘니'],
        '작성자':''
    },
    '싸다5':{
        'sense':{
            '1':{
                '뜻':'물건값이나 사람 또는 물건을 쓰는 데 드는 비용이 보통보다 낮다.',
                '예제':['물건을 싸게 팔다']
            },
            '2':{
                '뜻':'저지른 일 따위에 비추어서 받는 벌이 마땅하거나 오히려 적다.',
                '예제':['지은 죄로 보면 그는 맞아 죽어도 싸다']
            },
            '3':{
                '뜻':'그만한 가치가 있거나 그럴듯하다.',
                '예제':['한 푼 싸지도 않은 자존심']
            },
            '4':{
                '뜻':'말이나 일을 하는 것이 되거나 맵짜다.',
                '예제':['말을 떼면 싸게 하는 성미']
            }
        },
        '품사':'형용사',
        '발음':'',
        '어원':'싸다',
        '활용':['싸','싸니'],
        '작성자':''
    },
    '숨1':{
        'sense':{
            '1':{
                '뜻':'사람이나 동물이 코 또는 입으로 공기를 들이마시고 내쉬는 기운. 또는 그렇게 하는 일.',
                '예제':['숨을 쉬다']
            },
            '2':{
                '뜻':'채소 따위의 생생하고 빳빳한 기운.',
                '예제':[]
            }
        },
        '품사':'명사',
        '발음':'[숨:]',
        '어원':'숨',
        '활용':'',
        '작성자':''
    },
    '삯1':{
        'sense':{
            '1':{
                '뜻':'일한 데 대한 품값으로 주는 돈이나 물건.',
                '예제':['삯을 받고 일하다']
            },
            '2':{
                '뜻':'어떤 물건이나 시설을 이용하고 주는 돈. 임료.',
                '예제':['쟁기와 소를 빌린 삯을 지불하다']
            }
        },
        '품사':'명사',
        '발음':'[삭]',
        '어원':'삯',
        '활용':['삯이','삯만'],
        '작성자':''
    },
    '송송':{
        'sense':{
            '1':{
                '뜻':'연한 물건을 조금 잘게 빨리 써는 모양. 송송히.',
                '예제':['파를 송송 썰다']
            },
            '2':{
                '뜻':'작은 구멍이나 자국이 많이 나 있는 모양. 송송히.',
                '예제':['옷에 좀이 슬어 구멍이 송송 났다.']
            },
            '3':{
                '뜻':'살갗에 아주 작은 땀방울이나 소름 또는 털 따위가 많이 돋아난 모양. 송송히.',
                '예제':['땀이 송송 쏫은 이마']
            },
            '4':{
                '뜻':'바느질을 매우 촘촘하게 하는 모양. 송송히.',
                '예제':['송송 호다']
            }
        },
        '품사':'부사',
        '발음':'',
        '어원':'숑숑',
        '활용':'',
        '작성자':''
    }
}

# %%
dic['삯1']['sense']['2']['예제']
# Out:
# ['쟁기와 소를 빌린 삯을 지불하다']
